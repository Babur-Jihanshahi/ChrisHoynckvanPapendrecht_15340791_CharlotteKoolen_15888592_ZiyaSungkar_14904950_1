# %%
import pingouin as pg
import pandas as pd
import scipy.stats as stats
import numpy as np
from scipy.stats import ttest_1samp

# %%
# Import all the text files for the probabilistic sampling methods for the statistical tests

# Define constants
SIGNIFICANCE_LEVEL = 0.05
TRUE_VALUE = 1.506484
PAIRS = [('Latin', 'Random'), ('Latin', 'Orthogonal'), ('Random', 'Orthogonal')]

# Latin hypercube
df_l = pd.read_csv("latin.txt", header=1)
df_l.columns = ["grid_size", "max_iterations", "run", "total_points", "points_inside"]
df_l['fraction'] = (1 - df_l['points_inside'] / df_l['total_points']) * 9
df_l['method'] = 'Latin'
df_l["error"] = np.abs(df_l['fraction'] - TRUE_VALUE)

# Random
df_r = pd.read_csv("random.txt", header=1)
df_r.columns = ["grid_size", "max_iterations", "run", "total_points", "points_inside"]
df_r['fraction'] = (1 - df_r['points_inside'] / df_r['total_points']) * 9
df_r['method'] = 'Random'
df_r["error"] = np.abs(df_r['fraction'] - TRUE_VALUE)

# Orthogonal
df_o = pd.read_csv("orthogonal.txt", header=1)
df_o.columns = ["grid_size", "max_iterations", "run", "total_points", "points_inside"]
df_o['fraction'] = (1 - df_o['points_inside'] / df_o['total_points']) * 9
df_o['method'] = 'Orthogonal'
df_o["error"] = np.abs(df_o['fraction'] - TRUE_VALUE)

data_combined = pd.concat([df_l, df_r, df_o], ignore_index=True)
methods = data_combined['method'].unique()
grid_sizes = data_combined['grid_size'].unique()
iteration_bounds = data_combined['max_iterations'].unique()

# %%
# Hypotheses_0^1: for Deterministic data

# Deterministic
df_d = pd.read_csv("question2.txt", header=1)
df_d.columns = ["grid_size", "max_iterations", "total_points", "points_inside"]
df_d['fraction'] = (1 - df_d['points_inside'] / df_d['total_points']) * 9
df_d['method'] = 'Deterministic'
df_d["error"] = np.abs(df_d['fraction'] - TRUE_VALUE)

print("Deterministic sampling method\n")

# Calculate the smallest mean error for the largest grid size and iteration bound
mean_error_largest_df = df_d[(df_d['grid_size'] == 5000) & (df_d['max_iterations'] == 2000)]
mean_error_smallest = mean_error_largest_df['error'].mean()
print(f"Smallest mean error: {mean_error_smallest}\n")

# Grid sizes and iteration bounds
grid_sizes = [100, 500, 1000, 5000]
iteration_bounds = [50, 500, 2000]

# Loop over grid sizes and iteration bounds
for i, j in [(x, y) for x in iteration_bounds for y in iteration_bounds if x > y]:  # i > j
    for z, s in [(x, y) for x in grid_sizes for y in grid_sizes if x > y]:  # z > s

        # Filter for the current grid size and iteration conditions
        filtered_d = df_d[(df_d['grid_size'] == z) & (df_d['max_iterations'] == i)]

        # Calculate mean error for the filtered data
        mean_error = filtered_d['error'].mean()

        # Print results for the current combination
        print(f"Grid sizes: {z} > {s}")
        print(f"Iterations {i} > {j}")
        print(f"Mean error: {mean_error}")
        print(40*"-")
# Out:
# Deterministic sampling method
#
# Smallest mean error: 0.0013306400000001606
#
# Grid sizes: 500 > 100
# Iterations 500 > 50
# Mean error: 0.001196000000000197
# ----------------------------------------
# Grid sizes: 1000 > 100
# Iterations 500 > 50
# Mean error: 0.004913000000000167
# ----------------------------------------
# Grid sizes: 1000 > 500
# Iterations 500 > 50
# Mean error: 0.004913000000000167
# ----------------------------------------
# Grid sizes: 5000 > 100
# Iterations 500 > 50
# Mean error: 0.007230680000000156
# ----------------------------------------
# Grid sizes: 5000 > 500
# Iterations 500 > 50
# Mean error: 0.007230680000000156
# ----------------------------------------
# Grid sizes: 5000 > 1000
# Iterations 500 > 50
# Mean error: 0.007230680000000156
# ----------------------------------------
# Grid sizes: 500 > 100
# Iterations 2000 > 50
# Mean error: 0.004455999999999571
# ----------------------------------------
# Grid sizes: 1000 > 100
# Iterations 2000 > 50
# Mean error: 0.0010090000000002597
# ----------------------------------------
# Grid sizes: 1000 > 500
# Iterations 2000 > 50
# Mean error: 0.0010090000000002597
# ----------------------------------------
# Grid sizes: 5000 > 100
# Iterations 2000 > 50
# Mean error: 0.0013306400000001606
# ----------------------------------------
# Grid sizes: 5000 > 500
# Iterations 2000 > 50
# Mean error: 0.0013306400000001606
# ----------------------------------------
# Grid sizes: 5000 > 1000
# Iterations 2000 > 50
# Mean error: 0.0013306400000001606
# ----------------------------------------
# Grid sizes: 500 > 100
# Iterations 2000 > 500
# Mean error: 0.004455999999999571
# ----------------------------------------
# Grid sizes: 1000 > 100
# Iterations 2000 > 500
# Mean error: 0.0010090000000002597
# ----------------------------------------
# Grid sizes: 1000 > 500
# Iterations 2000 > 500
# Mean error: 0.0010090000000002597
# ----------------------------------------
# Grid sizes: 5000 > 100
# Iterations 2000 > 500
# Mean error: 0.0013306400000001606
# ----------------------------------------
# Grid sizes: 5000 > 500
# Iterations 2000 > 500
# Mean error: 0.0013306400000001606
# ----------------------------------------
# Grid sizes: 5000 > 1000
# Iterations 2000 > 500
# Mean error: 0.0013306400000001606
# ----------------------------------------

# %%
# One-sample T-test to test H_0^(1a): mu(2000,5000)=0 (done) (for every method seperately)

# Criteria for variables: grid size and iteration bound
grid_size = 5000
max_iter = 2000

# Subset the data for the specific grid size and iteration bound
subset = data_combined[
    (data_combined['grid_size'] == grid_size) & 
    (data_combined['max_iterations'] == max_iter)
]

# Get the sampling methods
methods = subset['method'].unique()

# Iterate over each sampling method
for method in methods:

    method_subset = subset[subset['method'] == method]

    # Perform 1-sample t-test for each method to evaluate with 0
    t_stat, p_value = ttest_1samp(method_subset['error'], 0)

    # Print results
    print(f"1-Sample t-test results for method: {method}")
    print(f"Mean error: {method_subset['error'].mean()}")
    print(f"t-statistic: {t_stat}")
    print(f"p-value: {p_value}")

    # Check significance
    if p_value < SIGNIFICANCE_LEVEL:
        print("Statistically significant difference")
    else:
        print("Statistically NOT significant difference")
    print(80*"-")
# Out:
# 1-Sample t-test results for method: Latin
# Mean error: 0.0018002960000000235
# t-statistic: 13.126121291762377
# p-value: 3.573944715828477e-07
# Statistically significant difference
# --------------------------------------------------------------------------------
# 1-Sample t-test results for method: Random
# Mean error: 0.002144384000000077
# t-statistic: 7.534387036390897
# p-value: 3.562106019150578e-05
# Statistically significant difference
# --------------------------------------------------------------------------------
# 1-Sample t-test results for method: Orthogonal
# Mean error: 0.0019087279999998152
# t-statistic: 200.80984621488287
# p-value: 9.580966296302393e-18
# Statistically significant difference
# --------------------------------------------------------------------------------

# %%
# Welch's t-test to test H_0^(1b): mu(i,s)=mu(j,s), where i > j (mean error) (within every method) (done)

# Loop through grid sizes
for grid_size in grid_sizes:
    # Subset the data for the current grid size
    grid_subset = data_combined[data_combined['grid_size'] == grid_size]
    
    # Loop through all pairs of iteration bounds
    for i in iteration_bounds:
        for j in iteration_bounds:
            if i > j:  # Only compare when i > j (iteration bounds)

                for method in data_combined['method'].unique():
                    method_subset = grid_subset[grid_subset['method'] == method]

                    data_i = method_subset[method_subset['max_iterations'] == i]['error']
                    data_j = method_subset[method_subset['max_iterations'] == j]['error']

                    # Check if either dataset is empty
                    if data_i.empty or data_j.empty:
                        print(f"Skipping test for {method}, grid size {grid_size}, iterations {i} > {j} due to empty data.")
                        continue

                    
                    # Perform Welch's t-test
                    welch_result = pg.ttest(data_i, data_j, paired=False, alternative='two-sided')
                    p_val = welch_result['p-val'].values[0]

                    # Print results
                    print(f"Welch's t-test between {method}")
                    print(f"Iteration bounds {i} > {j}")
                    print(f"Grid Size {grid_size}")
                    print(welch_result)
                    
                    # Check significance
                    if p_val < SIGNIFICANCE_LEVEL:
                        print("Statistically significant difference")
                    else:
                        print("Statistically NOT significant difference")
                    print(80*"-")
# Out:
# Welch's t-test between Latin
# Iteration bounds 500 > 50
# Grid Size 100
#                T        dof alternative     p-val           CI95%  cohen-d  \
# T-test -6.442062  13.734826   two-sided  0.000017  [-0.09, -0.04]  3.02402
#
#             BF10     power
# T-test  2154.637  0.999988
# Statistically significant difference
# --------------------------------------------------------------------------------
# Welch's t-test between Random
# Iteration bounds 500 > 50
# Grid Size 100
#                T        dof alternative     p-val           CI95%   cohen-d  \
# T-test -3.721085  14.882527   two-sided  0.002074  [-0.09, -0.03]  1.735625
#
#           BF10     power
# T-test  19.688  0.944836
# Statistically significant difference
# --------------------------------------------------------------------------------
# Welch's t-test between Orthogonal
# Iteration bounds 500 > 50
# Grid Size 100
#                 T        dof alternative         p-val           CI95%  \
# T-test -31.400833  14.279958   two-sided  1.391872e-14  [-0.08, -0.07]
#
#           cohen-d       BF10  power
# T-test  14.696424  1.147e+13    1.0
# Statistically significant difference
# --------------------------------------------------------------------------------
# Welch's t-test between Latin
# Iteration bounds 2000 > 50
# Grid Size 100
#                T        dof alternative     p-val           CI95%   cohen-d  \
# T-test -6.440685  13.699255   two-sided  0.000017  [-0.09, -0.04]  3.023952
#
#             BF10     power
# T-test  2149.688  0.999988
# Statistically significant difference
# --------------------------------------------------------------------------------
# Welch's t-test between Random
# Iteration bounds 2000 > 50
# Grid Size 100
#                T        dof alternative     p-val           CI95%   cohen-d  \
# T-test -3.755352  13.833088   two-sided  0.002172  [-0.09, -0.02]  1.761897
#
#           BF10     power
# T-test  20.863  0.950563
# Statistically significant difference
# --------------------------------------------------------------------------------
# Welch's t-test between Orthogonal
# Iteration bounds 2000 > 50
# Grid Size 100
#                 T        dof alternative         p-val           CI95%  \
# T-test -35.443386  11.535376   two-sided  3.902248e-13  [-0.08, -0.07]
#
#           cohen-d       BF10  power
# T-test  16.835679  7.705e+13    1.0
# Statistically significant difference
# --------------------------------------------------------------------------------
# Welch's t-test between Latin
# Iteration bounds 2000 > 500
# Grid Size 100
#                T  dof alternative     p-val          CI95%   cohen-d   BF10  \
# T-test  0.011604   18   two-sided  0.990869  [-0.02, 0.02]  0.005189  0.397
#
#            power
# T-test  0.050014
# Statistically NOT significant difference
# --------------------------------------------------------------------------------
# Welch's t-test between Random
# Iteration bounds 2000 > 500
# Grid Size 100
#                T  dof alternative     p-val          CI95%   cohen-d BF10  \
# T-test  0.130489   18   two-sided  0.897627  [-0.02, 0.03]  0.058357  0.4
#
#            power
# T-test  0.051754
# Statistically NOT significant difference
# --------------------------------------------------------------------------------
# Welch's t-test between Orthogonal
# Iteration bounds 2000 > 500
# Grid Size 100
#               T  dof alternative     p-val         CI95%   cohen-d   BF10  \
# T-test -1.74058   18   two-sided  0.098824  [-0.01, 0.0]  0.778411  1.103
#
#           power
# T-test  0.37764
# Statistically NOT significant difference
# --------------------------------------------------------------------------------
# Welch's t-test between Latin
# Iteration bounds 500 > 50
# Grid Size 500
#                 T  dof alternative         p-val           CI95%    cohen-d  \
# T-test -30.881892   18   two-sided  4.804235e-17  [-0.08, -0.07]  13.810802
#
#              BF10  power
# T-test  4.008e+13    1.0
# Statistically significant difference
# --------------------------------------------------------------------------------
# Welch's t-test between Random
# Iteration bounds 500 > 50
# Grid Size 500
#                 T  dof alternative         p-val           CI95%    cohen-d  \
# T-test -25.851744   18   two-sided  1.102091e-15  [-0.08, -0.07]  11.561252
#
#              BF10  power
# T-test  2.104e+12    1.0
# Statistically significant difference
# --------------------------------------------------------------------------------
# Welch's t-test between Orthogonal
# Iteration bounds 500 > 50
# Grid Size 500
#                  T  dof alternative         p-val           CI95%     cohen-d  \
# T-test -236.671072   18   two-sided  6.759605e-33  [-0.07, -0.07]  105.842521
#
#              BF10  power
# T-test  9.773e+24    1.0
# Statistically significant difference
# --------------------------------------------------------------------------------
# Welch's t-test between Latin
# Iteration bounds 2000 > 50
# Grid Size 500
#                 T  dof alternative         p-val           CI95%    cohen-d  \
# T-test -35.413856   18   two-sided  4.243196e-18  [-0.08, -0.07]  15.837558
#
#             BF10  power
# T-test  3.94e+14    1.0
# Statistically significant difference
# --------------------------------------------------------------------------------
# Welch's t-test between Random
# Iteration bounds 2000 > 50
# Grid Size 500
#                 T  dof alternative         p-val           CI95%    cohen-d  \
# T-test -31.587258   18   two-sided  3.221952e-17  [-0.08, -0.07]  14.126251
#
#              BF10  power
# T-test  5.839e+13    1.0
# Statistically significant difference
# --------------------------------------------------------------------------------
# Welch's t-test between Orthogonal
# Iteration bounds 2000 > 50
# Grid Size 500
#                  T  dof alternative         p-val           CI95%     cohen-d  \
# T-test -250.565185   18   two-sided  2.421531e-33  [-0.08, -0.08]  112.056157
#
#              BF10  power
# T-test  1.298e+25    1.0
# Statistically significant difference
# --------------------------------------------------------------------------------
# Welch's t-test between Latin
# Iteration bounds 2000 > 500
# Grid Size 500
#                T  dof alternative     p-val         CI95%   cohen-d   BF10  \
# T-test -1.157566   18   two-sided  0.262171  [-0.01, 0.0]  0.517679  0.633
#
#            power
# T-test  0.195061
# Statistically NOT significant difference
# --------------------------------------------------------------------------------
# Welch's t-test between Random
# Iteration bounds 2000 > 500
# Grid Size 500
#                T  dof alternative     p-val         CI95%   cohen-d   BF10  \
# T-test -1.700997   18   two-sided  0.106155  [-0.01, 0.0]  0.760709  1.056
#
#            power
# T-test  0.363533
# Statistically NOT significant difference
# --------------------------------------------------------------------------------
# Welch's t-test between Orthogonal
# Iteration bounds 2000 > 500
# Grid Size 500
#                 T  dof alternative         p-val           CI95%    cohen-d  \
# T-test -39.541064   18   two-sided  5.975185e-19  [-0.01, -0.01]  17.683301
#
#              BF10  power
# T-test  2.499e+15    1.0
# Statistically significant difference
# --------------------------------------------------------------------------------
# Welch's t-test between Latin
# Iteration bounds 500 > 50
# Grid Size 1000
#                 T  dof alternative         p-val           CI95%    cohen-d  \
# T-test -54.126191   18   two-sided  2.196081e-21  [-0.08, -0.07]  24.205969
#
#              BF10  power
# T-test  4.942e+17    1.0
# Statistically significant difference
# --------------------------------------------------------------------------------
# Welch's t-test between Random
# Iteration bounds 500 > 50
# Grid Size 1000
#                 T  dof alternative         p-val           CI95%    cohen-d  \
# T-test -48.855306   18   two-sided  1.372202e-20  [-0.08, -0.07]  21.848757
#
#              BF10  power
# T-test  8.774e+16    1.0
# Statistically significant difference
# --------------------------------------------------------------------------------
# Welch's t-test between Orthogonal
# Iteration bounds 500 > 50
# Grid Size 1000
#                  T  dof alternative         p-val           CI95%     cohen-d  \
# T-test -420.376341   18   two-sided  2.187059e-37  [-0.07, -0.07]  187.998015
#
#              BF10  power
# T-test  6.926e+25    1.0
# Statistically significant difference
# --------------------------------------------------------------------------------
# Welch's t-test between Latin
# Iteration bounds 2000 > 50
# Grid Size 1000
#                 T  dof alternative         p-val           CI95%    cohen-d  \
# T-test -66.234146   18   two-sided  5.902664e-23  [-0.08, -0.08]  29.620811
#
#              BF10  power
# T-test  1.499e+19    1.0
# Statistically significant difference
# --------------------------------------------------------------------------------
# Welch's t-test between Random
# Iteration bounds 2000 > 50
# Grid Size 1000
#                 T  dof alternative         p-val           CI95%    cohen-d  \
# T-test -56.155512   18   two-sided  1.136395e-21  [-0.08, -0.08]  25.113508
#
#              BF10  power
# T-test  9.201e+17    1.0
# Statistically significant difference
# --------------------------------------------------------------------------------
# Welch's t-test between Orthogonal
# Iteration bounds 2000 > 50
# Grid Size 1000
#                  T  dof alternative         p-val           CI95%     cohen-d  \
# T-test -457.255186   18   two-sided  4.814513e-38  [-0.08, -0.08]  204.490736
#
#              BF10  power
# T-test  8.108e+25    1.0
# Statistically significant difference
# --------------------------------------------------------------------------------
# Welch's t-test between Latin
# Iteration bounds 2000 > 500
# Grid Size 1000
#                T  dof alternative     p-val          CI95%   cohen-d    BF10  \
# T-test -3.933245   18   two-sided  0.000974  [-0.01, -0.0]  1.759001  30.626
#
#            power
# T-test  0.960452
# Statistically significant difference
# --------------------------------------------------------------------------------
# Welch's t-test between Random
# Iteration bounds 2000 > 500
# Grid Size 1000
#                T  dof alternative    p-val          CI95%   cohen-d    BF10  \
# T-test -4.075518   18   two-sided  0.00071  [-0.01, -0.0]  1.822627  39.437
#
#           power
# T-test  0.97061
# Statistically significant difference
# --------------------------------------------------------------------------------
# Welch's t-test between Orthogonal
# Iteration bounds 2000 > 500
# Grid Size 1000
#                  T  dof alternative         p-val           CI95%    cohen-d  \
# T-test -104.224319   18   two-sided  1.722410e-26  [-0.01, -0.01]  46.610532
#
#              BF10  power
# T-test  3.258e+22    1.0
# Statistically significant difference
# --------------------------------------------------------------------------------
# Welch's t-test between Latin
# Iteration bounds 500 > 50
# Grid Size 5000
#                  T  dof alternative         p-val           CI95%     cohen-d  \
# T-test -412.724114   18   two-sided  3.044094e-37  [-0.07, -0.07]  184.575835
#
#             BF10  power
# T-test  6.67e+25    1.0
# Statistically significant difference
# --------------------------------------------------------------------------------
# Welch's t-test between Random
# Iteration bounds 500 > 50
# Grid Size 5000
#                  T  dof alternative         p-val           CI95%   cohen-d  \
# T-test -181.945027   18   two-sided  7.669829e-31  [-0.08, -0.07]  81.36829
#
#              BF10  power
# T-test  4.186e+26    1.0
# Statistically significant difference
# --------------------------------------------------------------------------------
# Welch's t-test between Orthogonal
# Iteration bounds 500 > 50
# Grid Size 5000
#                   T  dof alternative         p-val           CI95%  \
# T-test -2608.812238   18   two-sided  1.174213e-51  [-0.07, -0.07]
#
#             cohen-d       BF10  power
# T-test  1166.696301  1.956e+26    1.0
# Statistically significant difference
# --------------------------------------------------------------------------------
# Welch's t-test between Latin
# Iteration bounds 2000 > 50
# Grid Size 5000
#                  T  dof alternative         p-val           CI95%    cohen-d  \
# T-test -450.831912   18   two-sided  6.210621e-38  [-0.08, -0.08]  201.61816
#
#              BF10  power
# T-test  7.909e+25    1.0
# Statistically significant difference
# --------------------------------------------------------------------------------
# Welch's t-test between Random
# Iteration bounds 2000 > 50
# Grid Size 5000
#                  T  dof alternative         p-val           CI95%    cohen-d  \
# T-test -196.175702   18   two-sided  1.978688e-31  [-0.08, -0.08]  87.732441
#
#              BF10  power
# T-test  1.505e+27    1.0
# Statistically significant difference
# --------------------------------------------------------------------------------
# Welch's t-test between Orthogonal
# Iteration bounds 2000 > 50
# Grid Size 5000
#                   T  dof alternative         p-val           CI95%  \
# T-test -2860.438444   18   two-sided  2.238373e-52  [-0.08, -0.08]
#
#             cohen-d       BF10  power
# T-test  1279.226961  1.965e+26    1.0
# Statistically significant difference
# --------------------------------------------------------------------------------
# Welch's t-test between Latin
# Iteration bounds 2000 > 500
# Grid Size 5000
#                T  dof alternative         p-val           CI95%    cohen-d  \
# T-test -29.69852   18   two-sided  9.582542e-17  [-0.01, -0.01]  13.281582
#
#              BF10  power
# T-test  2.093e+13    1.0
# Statistically significant difference
# --------------------------------------------------------------------------------
# Welch's t-test between Random
# Iteration bounds 2000 > 500
# Grid Size 5000
#                 T  dof alternative         p-val          CI95%   cohen-d  \
# T-test -14.451934   18   two-sided  2.399006e-11  [-0.01, -0.0]  6.463102
#
#              BF10  power
# T-test  1.826e+08    1.0
# Statistically significant difference
# --------------------------------------------------------------------------------
# Welch's t-test between Orthogonal
# Iteration bounds 2000 > 500
# Grid Size 5000
#                 T  dof alternative         p-val           CI95%     cohen-d  \
# T-test -405.98371   18   two-sided  4.094182e-37  [-0.01, -0.01]  181.561434
#
#              BF10  power
# T-test  6.442e+25    1.0
# Statistically significant difference
# --------------------------------------------------------------------------------
# /opt/anaconda3/lib/python3.12/site-packages/scipy/stats/_continuous_distns.py:7762: RuntimeWarning: invalid value encountered in _nct_sf
#   return np.clip(_boost._nct_sf(x, df, nc), 0, 1)
# /opt/anaconda3/lib/python3.12/site-packages/scipy/stats/_continuous_distns.py:7754: RuntimeWarning: invalid value encountered in _nct_cdf
#   return np.clip(_boost._nct_cdf(x, df, nc), 0, 1)

# %%
# Welch's t-test to test H_0^(1c): mu(i,s) = mu(i,s'), where s' > s (z denotes s') (mean error) (within every method) (done)

# Loop through iteration bounds
for max_iter in iteration_bounds:

    # Subset the data for the current iteration bound
    max_iter_subset = data_combined[data_combined['max_iterations'] == max_iter]
    
    # Loop through all pairs of grid sizes
    for s in grid_sizes:
        for z in grid_sizes:
            if z > s:  # Only compare when z > s (grid sizes)

                for method in data_combined['method'].unique():
                    method_subset = max_iter_subset[max_iter_subset['method'] == method]

                    data_s = method_subset[method_subset['grid_size'] == s]['error']
                    data_z = method_subset[method_subset['grid_size'] == z]['error']

                    # Perform Welch's t-test
                    welch_result = pg.ttest(data_z, data_s, paired=False, alternative='two-sided')
                    p_val = welch_result['p-val'].values[0]

                    # Print results
                    print(f"Welch's t-test for method: {method}")
                    print(f"Iteration bound: {max_iter}")
                    print(f"Grid sizes: {z} > {s}")
                    print(welch_result)
                    
                    # Check significance
                    if p_val < SIGNIFICANCE_LEVEL:
                        print("Statistically significant difference")
                    else:
                        print("Statistically NOT significant difference")
                    print(80 * "-")
# Out:
# Welch's t-test for method: Latin
# Iteration bound: 50
# Grid sizes: 500 > 100
#                T       dof alternative     p-val          CI95%   cohen-d  \
# T-test -0.690585  8.653533   two-sided  0.507924  [-0.03, 0.01]  0.333931
#
#          BF10    power
# T-test  0.478  0.10549
# Statistically NOT significant difference
# --------------------------------------------------------------------------------
# Welch's t-test for method: Random
# Iteration bound: 50
# Grid sizes: 500 > 100
#                T      dof alternative     p-val          CI95%   cohen-d  \
# T-test  0.273847  8.41324   two-sided  0.790806  [-0.03, 0.03]  0.132649
#
#          BF10     power
# T-test  0.416  0.058566
# Statistically NOT significant difference
# --------------------------------------------------------------------------------
# Welch's t-test for method: Orthogonal
# Iteration bound: 50
# Grid sizes: 500 > 100
#                T       dof alternative     p-val         CI95%   cohen-d  \
# T-test  0.475556  8.397528   two-sided  0.646516  [-0.0, 0.01]  0.230382
#
#          BF10     power
# T-test  0.438  0.076076
# Statistically NOT significant difference
# --------------------------------------------------------------------------------
# Welch's t-test for method: Latin
# Iteration bound: 50
# Grid sizes: 1000 > 100
#                T       dof alternative     p-val          CI95%   cohen-d  \
# T-test -0.571366  8.190245   two-sided  0.583087  [-0.03, 0.02]  0.277227
#
#          BF10     power
# T-test  0.454  0.087969
# Statistically NOT significant difference
# --------------------------------------------------------------------------------
# Welch's t-test for method: Random
# Iteration bound: 50
# Grid sizes: 1000 > 100
#                T       dof alternative    p-val          CI95%   cohen-d  \
# T-test  0.097633  8.123482   two-sided  0.92459  [-0.03, 0.03]  0.047396
#
#          BF10     power
# T-test  0.406  0.051089
# Statistically NOT significant difference
# --------------------------------------------------------------------------------
# Welch's t-test for method: Orthogonal
# Iteration bound: 50
# Grid sizes: 1000 > 100
#                T       dof alternative     p-val         CI95%  cohen-d  BF10  \
# T-test  0.739937  8.131315   two-sided  0.480154  [-0.0, 0.01]  0.35918  0.49
#
#            power
# T-test  0.114412
# Statistically NOT significant difference
# --------------------------------------------------------------------------------
# Welch's t-test for method: Latin
# Iteration bound: 50
# Grid sizes: 5000 > 100
#                T      dof alternative     p-val          CI95%   cohen-d  \
# T-test -0.562197  8.00273   two-sided  0.589377  [-0.02, 0.02]  0.273173
#
#          BF10     power
# T-test  0.452  0.086848
# Statistically NOT significant difference
# --------------------------------------------------------------------------------
# Welch's t-test for method: Random
# Iteration bound: 50
# Grid sizes: 5000 > 100
#                T       dof alternative     p-val          CI95%   cohen-d  \
# T-test  0.086635  8.008287   two-sided  0.933089  [-0.03, 0.03]  0.042094
#
#          BF10     power
# T-test  0.406  0.050859
# Statistically NOT significant difference
# --------------------------------------------------------------------------------
# Welch's t-test for method: Orthogonal
# Iteration bound: 50
# Grid sizes: 5000 > 100
#               T       dof alternative     p-val         CI95%   cohen-d  \
# T-test  0.63842  8.003098   two-sided  0.541035  [-0.0, 0.01]  0.310209
#
#          BF10     power
# T-test  0.467  0.097739
# Statistically NOT significant difference
# --------------------------------------------------------------------------------
# Welch's t-test for method: Latin
# Iteration bound: 50
# Grid sizes: 1000 > 500
#                T  dof alternative     p-val         CI95%  cohen-d   BF10  \
# T-test  0.565367   18   two-sided  0.578804  [-0.0, 0.01]  0.25284  0.445
#
#            power
# T-test  0.083482
# Statistically NOT significant difference
# --------------------------------------------------------------------------------
# Welch's t-test for method: Random
# Iteration bound: 50
# Grid sizes: 1000 > 500
#                T  dof alternative     p-val         CI95%   cohen-d   BF10  \
# T-test -0.979586   18   two-sided  0.340274  [-0.01, 0.0]  0.438084  0.556
#
#            power
# T-test  0.152995
# Statistically NOT significant difference
# --------------------------------------------------------------------------------
# Welch's t-test for method: Orthogonal
# Iteration bound: 50
# Grid sizes: 1000 > 500
#                T  dof alternative     p-val        CI95%   cohen-d   BF10  \
# T-test  1.439124   18   two-sided  0.167279  [-0.0, 0.0]  0.643596  0.808
#
#            power
# T-test  0.275664
# Statistically NOT significant difference
# --------------------------------------------------------------------------------
# Welch's t-test for method: Latin
# Iteration bound: 50
# Grid sizes: 5000 > 500
#               T  dof alternative     p-val        CI95%   cohen-d   BF10  \
# T-test  0.70286   18   two-sided  0.491134  [-0.0, 0.0]  0.314329  0.473
#
#            power
# T-test  0.102163
# Statistically NOT significant difference
# --------------------------------------------------------------------------------
# Welch's t-test for method: Random
# Iteration bound: 50
# Grid sizes: 5000 > 500
#                T  dof alternative     p-val         CI95%   cohen-d   BF10  \
# T-test -1.175376   18   two-sided  0.255158  [-0.01, 0.0]  0.525644  0.642
#
#            power
# T-test  0.199665
# Statistically NOT significant difference
# --------------------------------------------------------------------------------
# Welch's t-test for method: Orthogonal
# Iteration bound: 50
# Grid sizes: 5000 > 500
#                T  dof alternative    p-val        CI95%   cohen-d   BF10  \
# T-test  0.992962   18   two-sided  0.33389  [-0.0, 0.0]  0.444066  0.561
#
#            power
# T-test  0.155904
# Statistically NOT significant difference
# --------------------------------------------------------------------------------
# Welch's t-test for method: Latin
# Iteration bound: 50
# Grid sizes: 5000 > 1000
#                T  dof alternative     p-val        CI95%   cohen-d   BF10  \
# T-test  0.113903   18   two-sided  0.910575  [-0.0, 0.0]  0.050939  0.399
#
#            power
# T-test  0.051336
# Statistically NOT significant difference
# --------------------------------------------------------------------------------
# Welch's t-test for method: Random
# Iteration bound: 50
# Grid sizes: 5000 > 1000
#                T  dof alternative     p-val        CI95%  cohen-d BF10  \
# T-test -0.125108   18   two-sided  0.901825  [-0.0, 0.0]  0.05595  0.4
#
#            power
# T-test  0.051612
# Statistically NOT significant difference
# --------------------------------------------------------------------------------
# Welch's t-test for method: Orthogonal
# Iteration bound: 50
# Grid sizes: 5000 > 1000
#                T  dof alternative     p-val        CI95%   cohen-d   BF10  \
# T-test -1.140187   18   two-sided  0.269153  [-0.0, 0.0]  0.509907  0.624
#
#            power
# T-test  0.190637
# Statistically NOT significant difference
# --------------------------------------------------------------------------------
# Welch's t-test for method: Latin
# Iteration bound: 500
# Grid sizes: 500 > 100
#                T  dof alternative    p-val          CI95%   cohen-d   BF10  \
# T-test -2.347262   18   two-sided  0.03055  [-0.03, -0.0]  1.049728  2.363
#
#            power
# T-test  0.602963
# Statistically significant difference
# --------------------------------------------------------------------------------
# Welch's t-test for method: Random
# Iteration bound: 500
# Grid sizes: 500 > 100
#                T  dof alternative     p-val          CI95%   cohen-d   BF10  \
# T-test -1.184508   18   two-sided  0.251617  [-0.03, 0.01]  0.529728  0.647
#
#            power
# T-test  0.202052
# Statistically NOT significant difference
# --------------------------------------------------------------------------------
# Welch's t-test for method: Orthogonal
# Iteration bound: 500
# Grid sizes: 500 > 100
#                T  dof alternative     p-val        CI95%  cohen-d   BF10  \
# T-test -1.126195   18   two-sided  0.274874  [-0.0, 0.0]  0.50365  0.618
#
#            power
# T-test  0.187124
# Statistically NOT significant difference
# --------------------------------------------------------------------------------
# Welch's t-test for method: Latin
# Iteration bound: 500
# Grid sizes: 1000 > 100
#                T  dof alternative     p-val          CI95%   cohen-d   BF10  \
# T-test -2.329806   18   two-sided  0.031655  [-0.02, -0.0]  1.041921  2.307
#
#            power
# T-test  0.596596
# Statistically significant difference
# --------------------------------------------------------------------------------
# Welch's t-test for method: Random
# Iteration bound: 500
# Grid sizes: 1000 > 100
#                T  dof alternative     p-val          CI95%   cohen-d   BF10  \
# T-test -1.485229   18   two-sided  0.154787  [-0.03, 0.01]  0.664214  0.845
#
#           power
# T-test  0.29034
# Statistically NOT significant difference
# --------------------------------------------------------------------------------
# Welch's t-test for method: Orthogonal
# Iteration bound: 500
# Grid sizes: 1000 > 100
#                T  dof alternative     p-val        CI95%   cohen-d  BF10  \
# T-test -0.962888   18   two-sided  0.348362  [-0.0, 0.0]  0.430617  0.55
#
#            power
# T-test  0.149422
# Statistically NOT significant difference
# --------------------------------------------------------------------------------
# Welch's t-test for method: Latin
# Iteration bound: 500
# Grid sizes: 5000 > 100
#               T  dof alternative     p-val          CI95%   cohen-d   BF10  \
# T-test -2.38285   18   two-sided  0.028408  [-0.02, -0.0]  1.065643  2.483
#
#            power
# T-test  0.615855
# Statistically significant difference
# --------------------------------------------------------------------------------
# Welch's t-test for method: Random
# Iteration bound: 500
# Grid sizes: 5000 > 100
#                T  dof alternative     p-val          CI95%   cohen-d   BF10  \
# T-test -1.525254   18   two-sided  0.144574  [-0.03, 0.01]  0.682114  0.879
#
#            power
# T-test  0.303379
# Statistically NOT significant difference
# --------------------------------------------------------------------------------
# Welch's t-test for method: Orthogonal
# Iteration bound: 500
# Grid sizes: 5000 > 100
#                T  dof alternative    p-val        CI95%   cohen-d   BF10  \
# T-test -1.104815   18   two-sided  0.28379  [-0.0, 0.0]  0.494088  0.608
#
#            power
# T-test  0.181842
# Statistically NOT significant difference
# --------------------------------------------------------------------------------
# Welch's t-test for method: Latin
# Iteration bound: 500
# Grid sizes: 1000 > 500
#                T  dof alternative     p-val        CI95%   cohen-d   BF10  \
# T-test  0.227899   18   two-sided  0.822294  [-0.0, 0.0]  0.101919  0.405
#
#            power
# T-test  0.055362
# Statistically NOT significant difference
# --------------------------------------------------------------------------------
# Welch's t-test for method: Random
# Iteration bound: 500
# Grid sizes: 1000 > 500
#                T  dof alternative     p-val         CI95%   cohen-d   BF10  \
# T-test -1.185126   18   two-sided  0.251379  [-0.01, 0.0]  0.530005  0.647
#
#            power
# T-test  0.202215
# Statistically NOT significant difference
# --------------------------------------------------------------------------------
# Welch's t-test for method: Orthogonal
# Iteration bound: 500
# Grid sizes: 1000 > 500
#                T  dof alternative     p-val        CI95%   cohen-d   BF10  \
# T-test  2.051144   18   two-sided  0.055098  [-0.0, 0.0]  0.917299  1.596
#
#           power
# T-test  0.49261
# Statistically NOT significant difference
# --------------------------------------------------------------------------------
# Welch's t-test for method: Latin
# Iteration bound: 500
# Grid sizes: 5000 > 500
#               T  dof alternative     p-val        CI95%   cohen-d   BF10  \
# T-test  0.21173   18   two-sided  0.834697  [-0.0, 0.0]  0.094689  0.404
#
#            power
# T-test  0.054626
# Statistically NOT significant difference
# --------------------------------------------------------------------------------
# Welch's t-test for method: Random
# Iteration bound: 500
# Grid sizes: 5000 > 500
#                T  dof alternative     p-val         CI95%   cohen-d  BF10  \
# T-test -1.467452   18   two-sided  0.159509  [-0.01, 0.0]  0.656265  0.83
#
#            power
# T-test  0.284637
# Statistically NOT significant difference
# --------------------------------------------------------------------------------
# Welch's t-test for method: Orthogonal
# Iteration bound: 500
# Grid sizes: 5000 > 500
#                T  dof alternative     p-val        CI95%   cohen-d   BF10  \
# T-test  0.329263   18   two-sided  0.745757  [-0.0, 0.0]  0.147251  0.413
#
#            power
# T-test  0.061229
# Statistically NOT significant difference
# --------------------------------------------------------------------------------
# Welch's t-test for method: Latin
# Iteration bound: 500
# Grid sizes: 5000 > 1000
#                T  dof alternative     p-val        CI95%   cohen-d   BF10  \
# T-test -0.088643   18   two-sided  0.930344  [-0.0, 0.0]  0.039642  0.399
#
#            power
# T-test  0.050809
# Statistically NOT significant difference
# --------------------------------------------------------------------------------
# Welch's t-test for method: Random
# Iteration bound: 500
# Grid sizes: 5000 > 1000
#                T  dof alternative     p-val        CI95%   cohen-d   BF10  \
# T-test -0.281405   18   two-sided  0.781609  [-0.0, 0.0]  0.125848  0.409
#
#            power
# T-test  0.058188
# Statistically NOT significant difference
# --------------------------------------------------------------------------------
# Welch's t-test for method: Orthogonal
# Iteration bound: 500
# Grid sizes: 5000 > 1000
#                T  dof alternative     p-val         CI95%   cohen-d    BF10  \
# T-test -4.093595   18   two-sided  0.000682  [-0.0, -0.0]  1.830711  40.731
#
#           power
# T-test  0.97173
# Statistically significant difference
# --------------------------------------------------------------------------------
# Welch's t-test for method: Latin
# Iteration bound: 2000
# Grid sizes: 500 > 100
#                T  dof alternative     p-val          CI95%   cohen-d  BF10  \
# T-test -2.830015   18   two-sided  0.011099  [-0.03, -0.0]  1.265621  4.81
#
#            power
# T-test  0.763165
# Statistically significant difference
# --------------------------------------------------------------------------------
# Welch's t-test for method: Random
# Iteration bound: 2000
# Grid sizes: 500 > 100
#                T  dof alternative   p-val         CI95%   cohen-d  BF10  \
# T-test -2.022863   18   two-sided  0.0582  [-0.03, 0.0]  0.904652  1.54
#
#            power
# T-test  0.481963
# Statistically NOT significant difference
# --------------------------------------------------------------------------------
# Welch's t-test for method: Orthogonal
# Iteration bound: 2000
# Grid sizes: 500 > 100
#                T  dof alternative     p-val          CI95%   cohen-d    BF10  \
# T-test -4.893436   18   two-sided  0.000117  [-0.01, -0.0]  2.188411  173.01
#
#           power
# T-test  0.99608
# Statistically significant difference
# --------------------------------------------------------------------------------
# Welch's t-test for method: Latin
# Iteration bound: 2000
# Grid sizes: 1000 > 100
#                T  dof alternative     p-val           CI95%   cohen-d   BF10  \
# T-test -3.248778   18   two-sided  0.004457  [-0.03, -0.01]  1.452898  9.432
#
#            power
# T-test  0.866785
# Statistically significant difference
# --------------------------------------------------------------------------------
# Welch's t-test for method: Random
# Iteration bound: 2000
# Grid sizes: 1000 > 100
#                T  dof alternative     p-val          CI95%   cohen-d   BF10  \
# T-test -2.516855   18   two-sided  0.021539  [-0.04, -0.0]  1.125572  3.005
#
#            power
# T-test  0.663153
# Statistically significant difference
# --------------------------------------------------------------------------------
# Welch's t-test for method: Orthogonal
# Iteration bound: 2000
# Grid sizes: 1000 > 100
#                T  dof alternative     p-val          CI95%   cohen-d     BF10  \
# T-test -4.726788   18   two-sided  0.000168  [-0.01, -0.0]  2.113884  127.775
#
#           power
# T-test  0.99383
# Statistically significant difference
# --------------------------------------------------------------------------------
# Welch's t-test for method: Latin
# Iteration bound: 2000
# Grid sizes: 5000 > 100
#                T  dof alternative     p-val           CI95%   cohen-d    BF10  \
# T-test -3.472597   18   two-sided  0.002717  [-0.03, -0.01]  1.552992  13.743
#
#            power
# T-test  0.906951
# Statistically significant difference
# --------------------------------------------------------------------------------
# Welch's t-test for method: Random
# Iteration bound: 2000
# Grid sizes: 5000 > 100
#                T  dof alternative     p-val          CI95%   cohen-d   BF10  \
# T-test -2.615432   18   two-sided  0.017521  [-0.04, -0.0]  1.169657  3.473
#
#            power
# T-test  0.696408
# Statistically significant difference
# --------------------------------------------------------------------------------
# Welch's t-test for method: Orthogonal
# Iteration bound: 2000
# Grid sizes: 5000 > 100
#                T  dof alternative     p-val          CI95%   cohen-d    BF10  \
# T-test -4.997424   18   two-sided  0.000093  [-0.01, -0.0]  2.234916  209.04
#
#            power
# T-test  0.997079
# Statistically significant difference
# --------------------------------------------------------------------------------
# Welch's t-test for method: Latin
# Iteration bound: 2000
# Grid sizes: 1000 > 500
#                T  dof alternative     p-val         CI95%  cohen-d   BF10  \
# T-test -1.443381   18   two-sided  0.166092  [-0.01, 0.0]   0.6455  0.812
#
#            power
# T-test  0.277003
# Statistically NOT significant difference
# --------------------------------------------------------------------------------
# Welch's t-test for method: Random
# Iteration bound: 2000
# Grid sizes: 1000 > 500
#                T  dof alternative     p-val          CI95%   cohen-d   BF10  \
# T-test -2.493279   18   two-sided  0.022622  [-0.01, -0.0]  1.115028  2.905
#
#            power
# T-test  0.654992
# Statistically significant difference
# --------------------------------------------------------------------------------
# Welch's t-test for method: Orthogonal
# Iteration bound: 2000
# Grid sizes: 1000 > 500
#               T  dof alternative     p-val        CI95%   cohen-d   BF10  \
# T-test  1.55214   18   two-sided  0.138034  [-0.0, 0.0]  0.694138  0.903
#
#            power
# T-test  0.312286
# Statistically NOT significant difference
# --------------------------------------------------------------------------------
# Welch's t-test for method: Latin
# Iteration bound: 2000
# Grid sizes: 5000 > 500
#                T  dof alternative     p-val          CI95%   cohen-d   BF10  \
# T-test -2.535039   18   two-sided  0.020738  [-0.01, -0.0]  1.133704  3.086
#
#            power
# T-test  0.669394
# Statistically significant difference
# --------------------------------------------------------------------------------
# Welch's t-test for method: Random
# Iteration bound: 2000
# Grid sizes: 5000 > 500
#                T  dof alternative     p-val          CI95%   cohen-d    BF10  \
# T-test -3.411015   18   two-sided  0.003115  [-0.01, -0.0]  1.525452  12.379
#
#           power
# T-test  0.89692
# Statistically significant difference
# --------------------------------------------------------------------------------
# Welch's t-test for method: Orthogonal
# Iteration bound: 2000
# Grid sizes: 5000 > 500
#                T  dof alternative     p-val        CI95%   cohen-d   BF10  \
# T-test -0.549708   18   two-sided  0.589276  [-0.0, 0.0]  0.245837  0.442
#
#            power
# T-test  0.081625
# Statistically NOT significant difference
# --------------------------------------------------------------------------------
# Welch's t-test for method: Latin
# Iteration bound: 2000
# Grid sizes: 5000 > 1000
#                T  dof alternative     p-val        CI95%   cohen-d   BF10  \
# T-test -1.452588   18   two-sided  0.163548  [-0.0, 0.0]  0.649617  0.819
#
#           power
# T-test  0.27991
# Statistically NOT significant difference
# --------------------------------------------------------------------------------
# Welch's t-test for method: Random
# Iteration bound: 2000
# Grid sizes: 5000 > 1000
#               T  dof alternative     p-val        CI95%   cohen-d   BF10  \
# T-test -0.79533   18   two-sided  0.436784  [-0.0, 0.0]  0.355682  0.496
#
#            power
# T-test  0.117166
# Statistically NOT significant difference
# --------------------------------------------------------------------------------
# Welch's t-test for method: Orthogonal
# Iteration bound: 2000
# Grid sizes: 5000 > 1000
#                T  dof alternative     p-val         CI95%   cohen-d     BF10  \
# T-test -6.614752   18   two-sided  0.000003  [-0.0, -0.0]  2.958207  3755.21
#
#           power
# T-test  0.99999
# Statistically significant difference
# --------------------------------------------------------------------------------

# %%
# # Welch's t-test to test H_0^(1d): mu_Orth = mu_Rand = mu_LHS (mean error) (between method pairs) (done)

# Loop through the grid sizes and iteration bounds
for grid_size in grid_sizes:
    for max_iter in iteration_bounds:

        # Subset the data for the current grid size and max iterations
        subset = data_combined[
            (data_combined['grid_size'] == grid_size) & 
            (data_combined['max_iterations'] == max_iterations)
        ]
        
        # Perform pairwise Welch's t-tests for each pair of methods
        for method1, method2 in PAIRS:
            
            data1 = subset[subset['method'] == method1]['error']
            data2 = subset[subset['method'] == method2]['error']
            
            # Perform Welch's t-test using Pingouin's ttest function
            welch_result = pg.ttest(data1, data2, paired=False, alternative='two-sided')
            p_val = welch_result['p-val'].values[0]

            # Print results
            print(f"Welch's t-test for method: {method1} and {method2}")
            print(f"Iteration bound: {max_iter}")
            print(f"Grid size: {grid_size}")
            print(welch_result)
            
            # Check significance
            if p_val < SIGNIFICANCE_LEVEL:
                print("Statistically significant difference (p < 0.05)")
            else:
                print("Statistically NOT significant difference (p >= 0.05)")
            print(80 * "-")
# Out:
# Welch's t-test for method: Latin and Random
# Iteration bound: 50
# Grid size: 100
#                T  dof alternative     p-val          CI95%   cohen-d  BF10  \
# T-test -0.295275   18   two-sided  0.771162  [-0.02, 0.02]  0.132051  0.41
#
#           power
# T-test  0.05902
# Statistically NOT significant difference (p >= 0.05)
# --------------------------------------------------------------------------------
# Welch's t-test for method: Latin and Orthogonal
# Iteration bound: 50
# Grid size: 100
#                T  dof alternative     p-val        CI95%   cohen-d   BF10  \
# T-test  2.591406   18   two-sided  0.018429  [0.0, 0.03]  1.158912  3.352
#
#            power
# T-test  0.688438
# Statistically significant difference (p < 0.05)
# --------------------------------------------------------------------------------
# Welch's t-test for method: Random and Orthogonal
# Iteration bound: 50
# Grid size: 100
#                T  dof alternative     p-val         CI95%   cohen-d   BF10  \
# T-test  2.084271   18   two-sided  0.051656  [-0.0, 0.03]  0.932114  1.665
#
#            power
# T-test  0.505086
# Statistically NOT significant difference (p >= 0.05)
# --------------------------------------------------------------------------------
# Welch's t-test for method: Latin and Random
# Iteration bound: 500
# Grid size: 100
#                T  dof alternative     p-val          CI95%   cohen-d  BF10  \
# T-test -0.295275   18   two-sided  0.771162  [-0.02, 0.02]  0.132051  0.41
#
#           power
# T-test  0.05902
# Statistically NOT significant difference (p >= 0.05)
# --------------------------------------------------------------------------------
# Welch's t-test for method: Latin and Orthogonal
# Iteration bound: 500
# Grid size: 100
#                T  dof alternative     p-val        CI95%   cohen-d   BF10  \
# T-test  2.591406   18   two-sided  0.018429  [0.0, 0.03]  1.158912  3.352
#
#            power
# T-test  0.688438
# Statistically significant difference (p < 0.05)
# --------------------------------------------------------------------------------
# Welch's t-test for method: Random and Orthogonal
# Iteration bound: 500
# Grid size: 100
#                T  dof alternative     p-val         CI95%   cohen-d   BF10  \
# T-test  2.084271   18   two-sided  0.051656  [-0.0, 0.03]  0.932114  1.665
#
#            power
# T-test  0.505086
# Statistically NOT significant difference (p >= 0.05)
# --------------------------------------------------------------------------------
# Welch's t-test for method: Latin and Random
# Iteration bound: 2000
# Grid size: 100
#                T  dof alternative     p-val          CI95%   cohen-d  BF10  \
# T-test -0.295275   18   two-sided  0.771162  [-0.02, 0.02]  0.132051  0.41
#
#           power
# T-test  0.05902
# Statistically NOT significant difference (p >= 0.05)
# --------------------------------------------------------------------------------
# Welch's t-test for method: Latin and Orthogonal
# Iteration bound: 2000
# Grid size: 100
#                T  dof alternative     p-val        CI95%   cohen-d   BF10  \
# T-test  2.591406   18   two-sided  0.018429  [0.0, 0.03]  1.158912  3.352
#
#            power
# T-test  0.688438
# Statistically significant difference (p < 0.05)
# --------------------------------------------------------------------------------
# Welch's t-test for method: Random and Orthogonal
# Iteration bound: 2000
# Grid size: 100
#                T  dof alternative     p-val         CI95%   cohen-d   BF10  \
# T-test  2.084271   18   two-sided  0.051656  [-0.0, 0.03]  0.932114  1.665
#
#            power
# T-test  0.505086
# Statistically NOT significant difference (p >= 0.05)
# --------------------------------------------------------------------------------
# Welch's t-test for method: Latin and Random
# Iteration bound: 50
# Grid size: 500
#                T  dof alternative     p-val         CI95%   cohen-d   BF10  \
# T-test -1.037711   18   two-sided  0.313145  [-0.01, 0.0]  0.464079  0.579
#
#            power
# T-test  0.165936
# Statistically NOT significant difference (p >= 0.05)
# --------------------------------------------------------------------------------
# Welch's t-test for method: Latin and Orthogonal
# Iteration bound: 50
# Grid size: 500
#                T  dof alternative     p-val        CI95%   cohen-d   BF10  \
# T-test  2.402984   18   two-sided  0.027259  [0.0, 0.01]  1.074647  2.554
#
#            power
# T-test  0.623094
# Statistically significant difference (p < 0.05)
# --------------------------------------------------------------------------------
# Welch's t-test for method: Random and Orthogonal
# Iteration bound: 50
# Grid size: 500
#                T  dof alternative     p-val        CI95%   cohen-d    BF10  \
# T-test  3.604333   18   two-sided  0.002028  [0.0, 0.01]  1.611907  17.227
#
#            power
# T-test  0.925952
# Statistically significant difference (p < 0.05)
# --------------------------------------------------------------------------------
# Welch's t-test for method: Latin and Random
# Iteration bound: 500
# Grid size: 500
#                T  dof alternative     p-val         CI95%   cohen-d   BF10  \
# T-test -1.037711   18   two-sided  0.313145  [-0.01, 0.0]  0.464079  0.579
#
#            power
# T-test  0.165936
# Statistically NOT significant difference (p >= 0.05)
# --------------------------------------------------------------------------------
# Welch's t-test for method: Latin and Orthogonal
# Iteration bound: 500
# Grid size: 500
#                T  dof alternative     p-val        CI95%   cohen-d   BF10  \
# T-test  2.402984   18   two-sided  0.027259  [0.0, 0.01]  1.074647  2.554
#
#            power
# T-test  0.623094
# Statistically significant difference (p < 0.05)
# --------------------------------------------------------------------------------
# Welch's t-test for method: Random and Orthogonal
# Iteration bound: 500
# Grid size: 500
#                T  dof alternative     p-val        CI95%   cohen-d    BF10  \
# T-test  3.604333   18   two-sided  0.002028  [0.0, 0.01]  1.611907  17.227
#
#            power
# T-test  0.925952
# Statistically significant difference (p < 0.05)
# --------------------------------------------------------------------------------
# Welch's t-test for method: Latin and Random
# Iteration bound: 2000
# Grid size: 500
#                T  dof alternative     p-val         CI95%   cohen-d   BF10  \
# T-test -1.037711   18   two-sided  0.313145  [-0.01, 0.0]  0.464079  0.579
#
#            power
# T-test  0.165936
# Statistically NOT significant difference (p >= 0.05)
# --------------------------------------------------------------------------------
# Welch's t-test for method: Latin and Orthogonal
# Iteration bound: 2000
# Grid size: 500
#                T  dof alternative     p-val        CI95%   cohen-d   BF10  \
# T-test  2.402984   18   two-sided  0.027259  [0.0, 0.01]  1.074647  2.554
#
#            power
# T-test  0.623094
# Statistically significant difference (p < 0.05)
# --------------------------------------------------------------------------------
# Welch's t-test for method: Random and Orthogonal
# Iteration bound: 2000
# Grid size: 500
#                T  dof alternative     p-val        CI95%   cohen-d    BF10  \
# T-test  3.604333   18   two-sided  0.002028  [0.0, 0.01]  1.611907  17.227
#
#            power
# T-test  0.925952
# Statistically significant difference (p < 0.05)
# --------------------------------------------------------------------------------
# Welch's t-test for method: Latin and Random
# Iteration bound: 50
# Grid size: 1000
#                T  dof alternative     p-val        CI95%   cohen-d   BF10  \
# T-test  0.013648   18   two-sided  0.989261  [-0.0, 0.0]  0.006103  0.397
#
#            power
# T-test  0.050019
# Statistically NOT significant difference (p >= 0.05)
# --------------------------------------------------------------------------------
# Welch's t-test for method: Latin and Orthogonal
# Iteration bound: 50
# Grid size: 1000
#                T  dof alternative     p-val        CI95%   cohen-d   BF10  \
# T-test  0.994835   18   two-sided  0.333003  [-0.0, 0.0]  0.444904  0.562
#
#            power
# T-test  0.156314
# Statistically NOT significant difference (p >= 0.05)
# --------------------------------------------------------------------------------
# Welch's t-test for method: Random and Orthogonal
# Iteration bound: 50
# Grid size: 1000
#                T  dof alternative     p-val        CI95%   cohen-d   BF10  \
# T-test  0.830056   18   two-sided  0.417381  [-0.0, 0.0]  0.371212  0.506
#
#            power
# T-test  0.123313
# Statistically NOT significant difference (p >= 0.05)
# --------------------------------------------------------------------------------
# Welch's t-test for method: Latin and Random
# Iteration bound: 500
# Grid size: 1000
#                T  dof alternative     p-val        CI95%   cohen-d   BF10  \
# T-test  0.013648   18   two-sided  0.989261  [-0.0, 0.0]  0.006103  0.397
#
#            power
# T-test  0.050019
# Statistically NOT significant difference (p >= 0.05)
# --------------------------------------------------------------------------------
# Welch's t-test for method: Latin and Orthogonal
# Iteration bound: 500
# Grid size: 1000
#                T  dof alternative     p-val        CI95%   cohen-d   BF10  \
# T-test  0.994835   18   two-sided  0.333003  [-0.0, 0.0]  0.444904  0.562
#
#            power
# T-test  0.156314
# Statistically NOT significant difference (p >= 0.05)
# --------------------------------------------------------------------------------
# Welch's t-test for method: Random and Orthogonal
# Iteration bound: 500
# Grid size: 1000
#                T  dof alternative     p-val        CI95%   cohen-d   BF10  \
# T-test  0.830056   18   two-sided  0.417381  [-0.0, 0.0]  0.371212  0.506
#
#            power
# T-test  0.123313
# Statistically NOT significant difference (p >= 0.05)
# --------------------------------------------------------------------------------
# Welch's t-test for method: Latin and Random
# Iteration bound: 2000
# Grid size: 1000
#                T  dof alternative     p-val        CI95%   cohen-d   BF10  \
# T-test  0.013648   18   two-sided  0.989261  [-0.0, 0.0]  0.006103  0.397
#
#            power
# T-test  0.050019
# Statistically NOT significant difference (p >= 0.05)
# --------------------------------------------------------------------------------
# Welch's t-test for method: Latin and Orthogonal
# Iteration bound: 2000
# Grid size: 1000
#                T  dof alternative     p-val        CI95%   cohen-d   BF10  \
# T-test  0.994835   18   two-sided  0.333003  [-0.0, 0.0]  0.444904  0.562
#
#            power
# T-test  0.156314
# Statistically NOT significant difference (p >= 0.05)
# --------------------------------------------------------------------------------
# Welch's t-test for method: Random and Orthogonal
# Iteration bound: 2000
# Grid size: 1000
#                T  dof alternative     p-val        CI95%   cohen-d   BF10  \
# T-test  0.830056   18   two-sided  0.417381  [-0.0, 0.0]  0.371212  0.506
#
#            power
# T-test  0.123313
# Statistically NOT significant difference (p >= 0.05)
# --------------------------------------------------------------------------------
# Welch's t-test for method: Latin and Random
# Iteration bound: 50
# Grid size: 5000
#                T  dof alternative     p-val        CI95%   cohen-d   BF10  \
# T-test -1.089106   18   two-sided  0.290474  [-0.0, 0.0]  0.487063  0.601
#
#            power
# T-test  0.178026
# Statistically NOT significant difference (p >= 0.05)
# --------------------------------------------------------------------------------
# Welch's t-test for method: Latin and Orthogonal
# Iteration bound: 50
# Grid size: 5000
#                T  dof alternative     p-val        CI95%   cohen-d   BF10  \
# T-test -0.788696   18   two-sided  0.440555  [-0.0, 0.0]  0.352715  0.495
#
#            power
# T-test  0.116024
# Statistically NOT significant difference (p >= 0.05)
# --------------------------------------------------------------------------------
# Welch's t-test for method: Random and Orthogonal
# Iteration bound: 50
# Grid size: 5000
#                T  dof alternative     p-val        CI95%   cohen-d   BF10  \
# T-test  0.827526   18   two-sided  0.418775  [-0.0, 0.0]  0.370081  0.506
#
#            power
# T-test  0.122856
# Statistically NOT significant difference (p >= 0.05)
# --------------------------------------------------------------------------------
# Welch's t-test for method: Latin and Random
# Iteration bound: 500
# Grid size: 5000
#                T  dof alternative     p-val        CI95%   cohen-d   BF10  \
# T-test -1.089106   18   two-sided  0.290474  [-0.0, 0.0]  0.487063  0.601
#
#            power
# T-test  0.178026
# Statistically NOT significant difference (p >= 0.05)
# --------------------------------------------------------------------------------
# Welch's t-test for method: Latin and Orthogonal
# Iteration bound: 500
# Grid size: 5000
#                T  dof alternative     p-val        CI95%   cohen-d   BF10  \
# T-test -0.788696   18   two-sided  0.440555  [-0.0, 0.0]  0.352715  0.495
#
#            power
# T-test  0.116024
# Statistically NOT significant difference (p >= 0.05)
# --------------------------------------------------------------------------------
# Welch's t-test for method: Random and Orthogonal
# Iteration bound: 500
# Grid size: 5000
#                T  dof alternative     p-val        CI95%   cohen-d   BF10  \
# T-test  0.827526   18   two-sided  0.418775  [-0.0, 0.0]  0.370081  0.506
#
#            power
# T-test  0.122856
# Statistically NOT significant difference (p >= 0.05)
# --------------------------------------------------------------------------------
# Welch's t-test for method: Latin and Random
# Iteration bound: 2000
# Grid size: 5000
#                T  dof alternative     p-val        CI95%   cohen-d   BF10  \
# T-test -1.089106   18   two-sided  0.290474  [-0.0, 0.0]  0.487063  0.601
#
#            power
# T-test  0.178026
# Statistically NOT significant difference (p >= 0.05)
# --------------------------------------------------------------------------------
# Welch's t-test for method: Latin and Orthogonal
# Iteration bound: 2000
# Grid size: 5000
#                T  dof alternative     p-val        CI95%   cohen-d   BF10  \
# T-test -0.788696   18   two-sided  0.440555  [-0.0, 0.0]  0.352715  0.495
#
#            power
# T-test  0.116024
# Statistically NOT significant difference (p >= 0.05)
# --------------------------------------------------------------------------------
# Welch's t-test for method: Random and Orthogonal
# Iteration bound: 2000
# Grid size: 5000
#                T  dof alternative     p-val        CI95%   cohen-d   BF10  \
# T-test  0.827526   18   two-sided  0.418775  [-0.0, 0.0]  0.370081  0.506
#
#            power
# T-test  0.122856
# Statistically NOT significant difference (p >= 0.05)
# --------------------------------------------------------------------------------

# %%
# Fischer's f-test to test H_0^(2a): Var(X_LHS) = Var(X_Rand) = Var(X_Orth) (variance) (between method pairs) (done)

# Loop through grid sizes and iteration bounds
for grid_size in grid_sizes:
    for max_iter in iteration_bounds:
        
        # Subset the data for the current grid size and max iterations
        subset = data_combined[
            (data_combined['grid_size'] == grid_size) &
            (data_combined['max_iterations'] == max_iter)
        ]
        
        # Perform pairwise variance comparison using Fischer's F-test
        for method1, method2 in PAIRS:
            
            subset1 = subset[subset['method'] == method1]['fraction']
            subset2 = subset[subset['method'] == method2]['fraction']

            # Calculate variances
            var1 = subset1.var(ddof=1)  # Variance of method1
            var2 = subset2.var(ddof=1)  # Variance of method2

            # Ensure F-statistic is always the ratio of the larger variance to the smaller variance
            f_statistic = var1 / var2 if var1 >= var2 else var2 / var1
            
            # Degrees of freedom
            df1 = len(subset1) - 1
            df2 = len(subset2) - 1
            
            # Calculate p-value from F-distribution
            p_val = 1 - stats.f.cdf(f_statistic, df1, df2)
    
            # Print the results
            print(f"Fischer's F-test between {method1} and {method2}")
            print(f"Iteration bound: {max_iter}")
            print(f"Grid size: {grid_size}")
            print(f"F-statistic: {f_statistic}")
            print(f"p-value: {p_val}")
            
            # Check significance
            if p_val < SIGNIFICANCE_LEVEL:
                print("Statistically significant difference")
            else:
                print("Statistically NOT significant difference")
            print(80*"-")
# Out:
# Fischer's F-test between Latin and Random
# Iteration bound: 50
# Grid size: 100
# F-statistic: 2.2048356605088104
# p-value: 0.1421644946584777
# Statistically NOT significant difference
# --------------------------------------------------------------------------------
# Fischer's F-test between Latin and Orthogonal
# Iteration bound: 50
# Grid size: 100
# F-statistic: 20.967315716271695
# p-value: 0.00013449440241197763
# Statistically significant difference
# --------------------------------------------------------------------------------
# Fischer's F-test between Random and Orthogonal
# Iteration bound: 50
# Grid size: 100
# F-statistic: 46.229485396382664
# p-value: 6.683028238474442e-06
# Statistically significant difference
# --------------------------------------------------------------------------------
# Fischer's F-test between Latin and Random
# Iteration bound: 500
# Grid size: 100
# F-statistic: 1.8288753323948068
# p-value: 0.19094202465609933
# Statistically NOT significant difference
# --------------------------------------------------------------------------------
# Fischer's F-test between Latin and Orthogonal
# Iteration bound: 500
# Grid size: 100
# F-statistic: 15.158269116775251
# p-value: 0.00020157840029855212
# Statistically significant difference
# --------------------------------------------------------------------------------
# Fischer's F-test between Random and Orthogonal
# Iteration bound: 500
# Grid size: 100
# F-statistic: 27.722584469472274
# p-value: 1.6411260874482636e-05
# Statistically significant difference
# --------------------------------------------------------------------------------
# Fischer's F-test between Latin and Random
# Iteration bound: 2000
# Grid size: 100
# F-statistic: 1.6663814023282235
# p-value: 0.22929635341379417
# Statistically NOT significant difference
# --------------------------------------------------------------------------------
# Fischer's F-test between Latin and Orthogonal
# Iteration bound: 2000
# Grid size: 100
# F-statistic: 16.696222352710723
# p-value: 0.00013606782812736196
# Statistically significant difference
# --------------------------------------------------------------------------------
# Fischer's F-test between Random and Orthogonal
# Iteration bound: 2000
# Grid size: 100
# F-statistic: 27.822274417693926
# p-value: 1.6163090149401427e-05
# Statistically significant difference
# --------------------------------------------------------------------------------
# Fischer's F-test between Latin and Random
# Iteration bound: 50
# Grid size: 500
# F-statistic: 1.3940772770846441
# p-value: 0.3143177031943363
# Statistically NOT significant difference
# --------------------------------------------------------------------------------
# Fischer's F-test between Latin and Orthogonal
# Iteration bound: 50
# Grid size: 500
# F-statistic: 34.47166645152432
# p-value: 6.473173677634669e-06
# Statistically significant difference
# --------------------------------------------------------------------------------
# Fischer's F-test between Random and Orthogonal
# Iteration bound: 50
# Grid size: 500
# F-statistic: 48.0561669033111
# p-value: 1.53939968872141e-06
# Statistically significant difference
# --------------------------------------------------------------------------------
# Fischer's F-test between Latin and Random
# Iteration bound: 500
# Grid size: 500
# F-statistic: 1.036428757039926
# p-value: 0.4791836272237835
# Statistically NOT significant difference
# --------------------------------------------------------------------------------
# Fischer's F-test between Latin and Orthogonal
# Iteration bound: 500
# Grid size: 500
# F-statistic: 457.1486265535749
# p-value: 6.97869539934004e-11
# Statistically significant difference
# --------------------------------------------------------------------------------
# Fischer's F-test between Random and Orthogonal
# Iteration bound: 500
# Grid size: 500
# F-statistic: 441.08060824094287
# p-value: 8.193079548135529e-11
# Statistically significant difference
# --------------------------------------------------------------------------------
# Fischer's F-test between Latin and Random
# Iteration bound: 2000
# Grid size: 500
# F-statistic: 1.0793570828125068
# p-value: 0.4556482387210823
# Statistically NOT significant difference
# --------------------------------------------------------------------------------
# Fischer's F-test between Latin and Orthogonal
# Iteration bound: 2000
# Grid size: 500
# F-statistic: 340.44938704044023
# p-value: 2.6145963172297115e-10
# Statistically significant difference
# --------------------------------------------------------------------------------
# Fischer's F-test between Random and Orthogonal
# Iteration bound: 2000
# Grid size: 500
# F-statistic: 315.41868067731866
# p-value: 3.680483695589487e-10
# Statistically significant difference
# --------------------------------------------------------------------------------
# Fischer's F-test between Latin and Random
# Iteration bound: 50
# Grid size: 1000
# F-statistic: 1.4313136356969287
# p-value: 0.3008937402677816
# Statistically NOT significant difference
# --------------------------------------------------------------------------------
# Fischer's F-test between Latin and Orthogonal
# Iteration bound: 50
# Grid size: 1000
# F-statistic: 30.3726262660206
# p-value: 1.1128062944676387e-05
# Statistically significant difference
# --------------------------------------------------------------------------------
# Fischer's F-test between Random and Orthogonal
# Iteration bound: 50
# Grid size: 1000
# F-statistic: 43.47275412648198
# p-value: 2.3789989171962844e-06
# Statistically significant difference
# --------------------------------------------------------------------------------
# Fischer's F-test between Latin and Random
# Iteration bound: 500
# Grid size: 1000
# F-statistic: 1.0423966151844182
# p-value: 0.47584734702154197
# Statistically NOT significant difference
# --------------------------------------------------------------------------------
# Fischer's F-test between Latin and Orthogonal
# Iteration bound: 500
# Grid size: 1000
# F-statistic: 539.1839159809497
# p-value: 3.3287261835823756e-11
# Statistically significant difference
# --------------------------------------------------------------------------------
# Fischer's F-test between Random and Orthogonal
# Iteration bound: 500
# Grid size: 1000
# F-statistic: 562.0434889804217
# p-value: 2.7629343257729033e-11
# Statistically significant difference
# --------------------------------------------------------------------------------
# Fischer's F-test between Latin and Random
# Iteration bound: 2000
# Grid size: 1000
# F-statistic: 1.0711497144710924
# p-value: 0.4600647963955615
# Statistically NOT significant difference
# --------------------------------------------------------------------------------
# Fischer's F-test between Latin and Orthogonal
# Iteration bound: 2000
# Grid size: 1000
# F-statistic: 863.9505363953045
# p-value: 4.009792498038678e-12
# Statistically significant difference
# --------------------------------------------------------------------------------
# Fischer's F-test between Random and Orthogonal
# Iteration bound: 2000
# Grid size: 1000
# F-statistic: 806.563755489495
# p-value: 5.459854790501595e-12
# Statistically significant difference
# --------------------------------------------------------------------------------
# Fischer's F-test between Latin and Random
# Iteration bound: 50
# Grid size: 5000
# F-statistic: 6.692614794778985
# p-value: 0.00460985570786987
# Statistically significant difference
# --------------------------------------------------------------------------------
# Fischer's F-test between Latin and Orthogonal
# Iteration bound: 50
# Grid size: 5000
# F-statistic: 18.476847473284195
# p-value: 8.975893541884883e-05
# Statistically significant difference
# --------------------------------------------------------------------------------
# Fischer's F-test between Random and Orthogonal
# Iteration bound: 50
# Grid size: 5000
# F-statistic: 123.65842276057653
# p-value: 2.4003003029626768e-08
# Statistically significant difference
# --------------------------------------------------------------------------------
# Fischer's F-test between Latin and Random
# Iteration bound: 500
# Grid size: 5000
# F-statistic: 4.123849329268888
# p-value: 0.023215411660009178
# Statistically significant difference
# --------------------------------------------------------------------------------
# Fischer's F-test between Latin and Orthogonal
# Iteration bound: 500
# Grid size: 5000
# F-statistic: 168.3390051401916
# p-value: 6.084886816637436e-09
# Statistically significant difference
# --------------------------------------------------------------------------------
# Fischer's F-test between Random and Orthogonal
# Iteration bound: 500
# Grid size: 5000
# F-statistic: 694.2046934371708
# p-value: 1.070832311711456e-11
# Statistically significant difference
# --------------------------------------------------------------------------------
# Fischer's F-test between Latin and Random
# Iteration bound: 2000
# Grid size: 5000
# F-statistic: 4.306200604130325
# p-value: 0.02028318963472253
# Statistically significant difference
# --------------------------------------------------------------------------------
# Fischer's F-test between Latin and Orthogonal
# Iteration bound: 2000
# Grid size: 5000
# F-statistic: 208.20776645802673
# p-value: 2.3575673635534145e-09
# Statistically significant difference
# --------------------------------------------------------------------------------
# Fischer's F-test between Random and Orthogonal
# Iteration bound: 2000
# Grid size: 5000
# F-statistic: 896.5844097061802
# p-value: 3.3946179200938786e-12
# Statistically significant difference
# --------------------------------------------------------------------------------

# %%
# Fischer's f-test to test H_0^(2b): Var(X(i,s)) = Var(X(j,s)), where i > j (variance) (within every method)

# Loop through grid sizes
for grid_size in grid_sizes:
    
    # Subset the data for the current grid size
    grid_subset = data_combined[data_combined['grid_size'] == grid_size]
    
    # Loop through all pairs of iteration bounds
    for i in iteration_bounds:
        for j in iteration_bounds:
            if i > j:  # Only compare when i > j (iteration bounds)

                for method in data_combined['method'].unique():
                    method_subset = grid_subset[grid_subset['method'] == method]

                    data_i = method_subset[method_subset['max_iterations'] == i]['fraction']
                    data_j = method_subset[method_subset['max_iterations'] == j]['fraction']

                    # Calculate variances
                    var1 = data_i.var(ddof=1)  # Variance of i
                    var2 = data_j.var(ddof=1)  # Variance of j

                    # Ensure F-statistic is always the ratio of the larger variance to the smaller variance
                    f_statistic = var1 / var2 if var1 >= var2 else var2 / var1
                    
                    # Degrees of freedom
                    df1 = len(data_i) - 1
                    df2 = len(data_j) - 1
                    
                    # Calculate p-value from F-distribution
                    p_val = 1 - stats.f.cdf(f_statistic, df1, df2)
            
                    # Print the results
                    print(f"Fischer's F-test for method: {method}")
                    print(f"Iteration bound: {max_iter}")
                    print(f"Grid size: {grid_size}")
                    print(f"F-statistic: {f_statistic}")
                    print(f"p-value: {p_val}")
                    
                    # Check significance
                    if p_val < SIGNIFICANCE_LEVEL:
                        print("Statistically significant difference")
                    else:
                        print("Statistically NOT significant difference")
                    print(80*"-")
# Out:
# Fischer's F-test for method: Latin
# Iteration bound: 2000
# Grid size: 100
# F-statistic: 1.0177572883154873
# p-value: 0.4955350773795961
# Statistically NOT significant difference
# --------------------------------------------------------------------------------
# Fischer's F-test for method: Random
# Iteration bound: 2000
# Grid size: 100
# F-statistic: 1.184535009693248
# p-value: 0.4109504419856169
# Statistically NOT significant difference
# --------------------------------------------------------------------------------
# Fischer's F-test for method: Orthogonal
# Iteration bound: 2000
# Grid size: 100
# F-statistic: 1.4077885952711693
# p-value: 0.3202798853587512
# Statistically NOT significant difference
# --------------------------------------------------------------------------------
# Fischer's F-test for method: Latin
# Iteration bound: 2000
# Grid size: 100
# F-statistic: 1.1316506915193785
# p-value: 0.4361146748488486
# Statistically NOT significant difference
# --------------------------------------------------------------------------------
# Fischer's F-test for method: Random
# Iteration bound: 2000
# Grid size: 100
# F-statistic: 1.169201654660058
# p-value: 0.41809215881238715
# Statistically NOT significant difference
# --------------------------------------------------------------------------------
# Fischer's F-test for method: Orthogonal
# Iteration bound: 2000
# Grid size: 100
# F-statistic: 1.421140472878985
# p-value: 0.3155880538907827
# Statistically NOT significant difference
# --------------------------------------------------------------------------------
# Fischer's F-test for method: Latin
# Iteration bound: 2000
# Grid size: 100
# F-statistic: 1.1119062516294025
# p-value: 0.43851774214831885
# Statistically NOT significant difference
# --------------------------------------------------------------------------------
# Fischer's F-test for method: Random
# Iteration bound: 2000
# Grid size: 100
# F-statistic: 1.013114380203001
# p-value: 0.4924168461124936
# Statistically NOT significant difference
# --------------------------------------------------------------------------------
# Fischer's F-test for method: Orthogonal
# Iteration bound: 2000
# Grid size: 100
# F-statistic: 1.0094842916419875
# p-value: 0.49450584319358504
# Statistically NOT significant difference
# --------------------------------------------------------------------------------
# Fischer's F-test for method: Latin
# Iteration bound: 2000
# Grid size: 500
# F-statistic: 1.3086969017270766
# p-value: 0.3475504224466005
# Statistically NOT significant difference
# --------------------------------------------------------------------------------
# Fischer's F-test for method: Random
# Iteration bound: 2000
# Grid size: 500
# F-statistic: 1.104046152779662
# p-value: 0.4425983575305039
# Statistically NOT significant difference
# --------------------------------------------------------------------------------
# Fischer's F-test for method: Orthogonal
# Iteration bound: 2000
# Grid size: 500
# F-statistic: 10.133420536305266
# p-value: 0.0009898740681852924
# Statistically significant difference
# --------------------------------------------------------------------------------
# Fischer's F-test for method: Latin
# Iteration bound: 2000
# Grid size: 500
# F-statistic: 1.3648788438207016
# p-value: 0.32528950818256885
# Statistically NOT significant difference
# --------------------------------------------------------------------------------
# Fischer's F-test for method: Random
# Iteration bound: 2000
# Grid size: 500
# F-statistic: 1.1024474368707786
# p-value: 0.4434327023445507
# Statistically NOT significant difference
# --------------------------------------------------------------------------------
# Fischer's F-test for method: Orthogonal
# Iteration bound: 2000
# Grid size: 500
# F-statistic: 7.2359603035654
# p-value: 0.0034838763768800796
# Statistically significant difference
# --------------------------------------------------------------------------------
# Fischer's F-test for method: Latin
# Iteration bound: 2000
# Grid size: 500
# F-statistic: 1.0429296822048575
# p-value: 0.47555035339296936
# Statistically NOT significant difference
# --------------------------------------------------------------------------------
# Fischer's F-test for method: Random
# Iteration bound: 2000
# Grid size: 500
# F-statistic: 1.0014501515949108
# p-value: 0.49915654792068
# Statistically NOT significant difference
# --------------------------------------------------------------------------------
# Fischer's F-test for method: Orthogonal
# Iteration bound: 2000
# Grid size: 500
# F-statistic: 1.4004251144540125
# p-value: 0.31198479525030154
# Statistically NOT significant difference
# --------------------------------------------------------------------------------
# Fischer's F-test for method: Latin
# Iteration bound: 2000
# Grid size: 1000
# F-statistic: 1.0986672547556897
# p-value: 0.4454113949195587
# Statistically NOT significant difference
# --------------------------------------------------------------------------------
# Fischer's F-test for method: Random
# Iteration bound: 2000
# Grid size: 1000
# F-statistic: 1.2497859424549647
# p-value: 0.3725951170176727
# Statistically NOT significant difference
# --------------------------------------------------------------------------------
# Fischer's F-test for method: Orthogonal
# Iteration bound: 2000
# Grid size: 1000
# F-statistic: 16.15802968296817
# p-value: 0.0001555291877329834
# Statistically significant difference
# --------------------------------------------------------------------------------
# Fischer's F-test for method: Latin
# Iteration bound: 2000
# Grid size: 1000
# F-statistic: 1.2055902961277678
# p-value: 0.39258278765950383
# Statistically NOT significant difference
# --------------------------------------------------------------------------------
# Fischer's F-test for method: Random
# Iteration bound: 2000
# Grid size: 1000
# F-statistic: 1.2717016693976972
# p-value: 0.36306872419947234
# Statistically NOT significant difference
# --------------------------------------------------------------------------------
# Fischer's F-test for method: Orthogonal
# Iteration bound: 2000
# Grid size: 1000
# F-statistic: 23.59428324571789
# p-value: 3.242765836375394e-05
# Statistically significant difference
# --------------------------------------------------------------------------------
# Fischer's F-test for method: Latin
# Iteration bound: 2000
# Grid size: 1000
# F-statistic: 1.097320677310852
# p-value: 0.44611824138284906
# Statistically NOT significant difference
# --------------------------------------------------------------------------------
# Fischer's F-test for method: Random
# Iteration bound: 2000
# Grid size: 1000
# F-statistic: 1.0175355844535132
# p-value: 0.4898829751020165
# Statistically NOT significant difference
# --------------------------------------------------------------------------------
# Fischer's F-test for method: Orthogonal
# Iteration bound: 2000
# Grid size: 1000
# F-statistic: 1.4602203182352185
# p-value: 0.2908969627259803
# Statistically NOT significant difference
# --------------------------------------------------------------------------------
# Fischer's F-test for method: Latin
# Iteration bound: 2000
# Grid size: 5000
# F-statistic: 1.5272091481693322
# p-value: 0.26908621638098995
# Statistically NOT significant difference
# --------------------------------------------------------------------------------
# Fischer's F-test for method: Random
# Iteration bound: 2000
# Grid size: 5000
# F-statistic: 1.0626604636799029
# p-value: 0.46467433084703147
# Statistically NOT significant difference
# --------------------------------------------------------------------------------
# Fischer's F-test for method: Orthogonal
# Iteration bound: 2000
# Grid size: 5000
# F-statistic: 5.965658181206366
# p-value: 0.006901228470707954
# Statistically significant difference
# --------------------------------------------------------------------------------
# Fischer's F-test for method: Latin
# Iteration bound: 2000
# Grid size: 5000
# F-statistic: 1.4625393968951221
# p-value: 0.290110622004227
# Statistically NOT significant difference
# --------------------------------------------------------------------------------
# Fischer's F-test for method: Random
# Iteration bound: 2000
# Grid size: 5000
# F-statistic: 1.0626591791131843
# p-value: 0.4646750315276649
# Statistically NOT significant difference
# --------------------------------------------------------------------------------
# Fischer's F-test for method: Orthogonal
# Iteration bound: 2000
# Grid size: 5000
# F-statistic: 7.7048019176886875
# p-value: 0.0027718691150604435
# Statistically significant difference
# --------------------------------------------------------------------------------
# Fischer's F-test for method: Latin
# Iteration bound: 2000
# Grid size: 5000
# F-statistic: 1.0442174422183086
# p-value: 0.4748335744912623
# Statistically NOT significant difference
# --------------------------------------------------------------------------------
# Fischer's F-test for method: Random
# Iteration bound: 2000
# Grid size: 5000
# F-statistic: 1.0000012088228698
# p-value: 0.4999992964022164
# Statistically NOT significant difference
# --------------------------------------------------------------------------------
# Fischer's F-test for method: Orthogonal
# Iteration bound: 2000
# Grid size: 5000
# F-statistic: 1.2915258775571743
# p-value: 0.3546662653363709
# Statistically NOT significant difference
# --------------------------------------------------------------------------------

# %%
# Fischer's f-test to test H_0^(2c): Var(X(i,s)) = Var(X(i,s')), where s' > s (z denotes s') (variance) (within every method) (done)

# Loop through iteration bounds
for max_iter in iteration_bounds:

    # Subset the data for the current iteration bound
    max_iter_subset = data_combined[data_combined['max_iterations'] == max_iter]
    
    # Loop through all pairs of grid sizes
    for s in grid_sizes:
        for z in grid_sizes:
            if z > s:  # Only compare when z > s (grid sizes)

                for method in data_combined['method'].unique():
                    method_subset = max_iter_subset[max_iter_subset['method'] == method]
        
                    data_s = method_subset[method_subset['grid_size'] == s]['fraction']
                    data_z = method_subset[method_subset['grid_size'] == z]['fraction']

                    # Calculate variances
                    var1 = data_s.var(ddof=1)  # Variance of s
                    var2 = data_z.var(ddof=1)  # Variance of z

                    # Ensure F-statistic is always the ratio of the larger variance to the smaller variance
                    f_statistic = var1 / var2 if var1 >= var2 else var2 / var1
                    
                    # Degrees of freedom
                    df1 = len(data_s) - 1
                    df2 = len(data_z) - 1
                    
                    # Calculate p-value from F-distribution
                    p_val = 1 - stats.f.cdf(f_statistic, df1, df2)
            
                    # Print the results
                    print(f"Fischer's F-test for method: {method}")
                    print(f"Iteration bound: {max_iter}")
                    print(f"Grid size: {grid_size}")
                    print(f"F-statistic: {f_statistic}")
                    print(f"p-value: {p_val}")
                    
                    # Check significance
                    if p_val < SIGNIFICANCE_LEVEL:
                        print("Statistically significant difference")
                    else:
                        print("Statistically NOT significant difference")
                    print(80*"-")
# Out:
# Fischer's F-test for method: Latin
# Iteration bound: 50
# Grid size: 5000
# F-statistic: 22.051387697902147
# p-value: 4.841089714757718e-05
# Statistically significant difference
# --------------------------------------------------------------------------------
# Fischer's F-test for method: Random
# Iteration bound: 50
# Grid size: 5000
# F-statistic: 34.87589013839718
# p-value: 6.970256656635421e-06
# Statistically significant difference
# --------------------------------------------------------------------------------
# Fischer's F-test for method: Orthogonal
# Iteration bound: 50
# Grid size: 5000
# F-statistic: 36.25395314314919
# p-value: 5.903284096553385e-06
# Statistically significant difference
# --------------------------------------------------------------------------------
# Fischer's F-test for method: Latin
# Iteration bound: 50
# Grid size: 5000
# F-statistic: 75.73238194178128
# p-value: 2.3938455240291034e-07
# Statistically significant difference
# --------------------------------------------------------------------------------
# Fischer's F-test for method: Random
# Iteration bound: 50
# Grid size: 5000
# F-statistic: 116.66028478741414
# p-value: 3.550127081197729e-08
# Statistically significant difference
# --------------------------------------------------------------------------------
# Fischer's F-test for method: Orthogonal
# Iteration bound: 50
# Grid size: 5000
# F-statistic: 109.70366279018663
# p-value: 4.662031682922674e-08
# Statistically significant difference
# --------------------------------------------------------------------------------
# Fischer's F-test for method: Latin
# Iteration bound: 50
# Grid size: 5000
# F-statistic: 5274.445454210034
# p-value: 1.3322676295501878e-15
# Statistically significant difference
# --------------------------------------------------------------------------------
# Fischer's F-test for method: Random
# Iteration bound: 50
# Grid size: 5000
# F-statistic: 1737.629578789304
# p-value: 1.9884094371036554e-13
# Statistically significant difference
# --------------------------------------------------------------------------------
# Fischer's F-test for method: Orthogonal
# Iteration bound: 50
# Grid size: 5000
# F-statistic: 4647.95424852433
# p-value: 2.3314683517128287e-15
# Statistically significant difference
# --------------------------------------------------------------------------------
# Fischer's F-test for method: Latin
# Iteration bound: 50
# Grid size: 5000
# F-statistic: 3.4343590063035383
# p-value: 0.04014562041287184
# Statistically significant difference
# --------------------------------------------------------------------------------
# Fischer's F-test for method: Random
# Iteration bound: 50
# Grid size: 5000
# F-statistic: 3.3450123946506842
# p-value: 0.043301644887938306
# Statistically significant difference
# --------------------------------------------------------------------------------
# Fischer's F-test for method: Orthogonal
# Iteration bound: 50
# Grid size: 5000
# F-statistic: 3.0259779494120362
# p-value: 0.057291539910299116
# Statistically NOT significant difference
# --------------------------------------------------------------------------------
# Fischer's F-test for method: Latin
# Iteration bound: 50
# Grid size: 5000
# F-statistic: 239.18882233029788
# p-value: 1.2686621753132954e-09
# Statistically significant difference
# --------------------------------------------------------------------------------
# Fischer's F-test for method: Random
# Iteration bound: 50
# Grid size: 5000
# F-statistic: 49.823232378984706
# p-value: 1.3154889609845455e-06
# Statistically significant difference
# --------------------------------------------------------------------------------
# Fischer's F-test for method: Orthogonal
# Iteration bound: 50
# Grid size: 5000
# F-statistic: 128.20544645633055
# p-value: 2.0445719006723095e-08
# Statistically significant difference
# --------------------------------------------------------------------------------
# Fischer's F-test for method: Latin
# Iteration bound: 50
# Grid size: 5000
# F-statistic: 69.64584130292805
# p-value: 3.0369092962612143e-07
# Statistically significant difference
# --------------------------------------------------------------------------------
# Fischer's F-test for method: Random
# Iteration bound: 50
# Grid size: 5000
# F-statistic: 14.894782589942448
# p-value: 0.00021638997436379537
# Statistically significant difference
# --------------------------------------------------------------------------------
# Fischer's F-test for method: Orthogonal
# Iteration bound: 50
# Grid size: 5000
# F-statistic: 42.368268572889484
# p-value: 2.659613162370178e-06
# Statistically significant difference
# --------------------------------------------------------------------------------
# Fischer's F-test for method: Latin
# Iteration bound: 500
# Grid size: 5000
# F-statistic: 17.14908969173274
# p-value: 0.00012195533089542909
# Statistically significant difference
# --------------------------------------------------------------------------------
# Fischer's F-test for method: Random
# Iteration bound: 500
# Grid size: 5000
# F-statistic: 32.50608214782513
# p-value: 8.325794768837547e-06
# Statistically significant difference
# --------------------------------------------------------------------------------
# Fischer's F-test for method: Orthogonal
# Iteration bound: 500
# Grid size: 5000
# F-statistic: 517.1885219100461
# p-value: 4.012568055600241e-11
# Statistically significant difference
# --------------------------------------------------------------------------------
# Fischer's F-test for method: Latin
# Iteration bound: 500
# Grid size: 5000
# F-statistic: 70.1551660424063
# p-value: 2.9411685620317485e-07
# Statistically significant difference
# --------------------------------------------------------------------------------
# Fischer's F-test for method: Random
# Iteration bound: 500
# Grid size: 5000
# F-statistic: 123.08659750618938
# p-value: 2.4502178952445774e-08
# Statistically significant difference
# --------------------------------------------------------------------------------
# Fischer's F-test for method: Orthogonal
# Iteration bound: 500
# Grid size: 5000
# F-statistic: 2495.439080915693
# p-value: 3.4083846855992306e-14
# Statistically significant difference
# --------------------------------------------------------------------------------
# Fischer's F-test for method: Latin
# Iteration bound: 500
# Grid size: 5000
# F-statistic: 3514.9771786526476
# p-value: 7.327471962526033e-15
# Statistically significant difference
# --------------------------------------------------------------------------------
# Fischer's F-test for method: Random
# Iteration bound: 500
# Grid size: 5000
# F-statistic: 1558.8481883522682
# p-value: 2.8266278206956486e-13
# Statistically significant difference
# --------------------------------------------------------------------------------
# Fischer's F-test for method: Orthogonal
# Iteration bound: 500
# Grid size: 5000
# F-statistic: 39035.3118015326
# p-value: 1.1102230246251565e-16
# Statistically significant difference
# --------------------------------------------------------------------------------
# Fischer's F-test for method: Latin
# Iteration bound: 500
# Grid size: 5000
# F-statistic: 4.09089737726585
# p-value: 0.02379862616567463
# Statistically significant difference
# --------------------------------------------------------------------------------
# Fischer's F-test for method: Random
# Iteration bound: 500
# Grid size: 5000
# F-statistic: 3.7865712929180138
# p-value: 0.030115177070341947
# Statistically significant difference
# --------------------------------------------------------------------------------
# Fischer's F-test for method: Orthogonal
# Iteration bound: 500
# Grid size: 5000
# F-statistic: 4.825008628767908
# p-value: 0.014088889700561769
# Statistically significant difference
# --------------------------------------------------------------------------------
# Fischer's F-test for method: Latin
# Iteration bound: 500
# Grid size: 5000
# F-statistic: 204.96581695220553
# p-value: 2.5286699401050328e-09
# Statistically significant difference
# --------------------------------------------------------------------------------
# Fischer's F-test for method: Random
# Iteration bound: 500
# Grid size: 5000
# F-statistic: 47.95558508906817
# p-value: 1.5534942356953962e-06
# Statistically significant difference
# --------------------------------------------------------------------------------
# Fischer's F-test for method: Orthogonal
# Iteration bound: 500
# Grid size: 5000
# F-statistic: 75.4759824471162
# p-value: 2.1321344301217238e-07
# Statistically significant difference
# --------------------------------------------------------------------------------
# Fischer's F-test for method: Latin
# Iteration bound: 500
# Grid size: 5000
# F-statistic: 50.1028987163678
# p-value: 1.283803277907225e-06
# Statistically significant difference
# --------------------------------------------------------------------------------
# Fischer's F-test for method: Random
# Iteration bound: 500
# Grid size: 5000
# F-statistic: 12.664646029181869
# p-value: 0.0004142287285989754
# Statistically significant difference
# --------------------------------------------------------------------------------
# Fischer's F-test for method: Orthogonal
# Iteration bound: 500
# Grid size: 5000
# F-statistic: 15.642662688126505
# p-value: 0.00017744538865094306
# Statistically significant difference
# --------------------------------------------------------------------------------
# Fischer's F-test for method: Latin
# Iteration bound: 2000
# Grid size: 5000
# F-statistic: 18.28328444701942
# p-value: 9.374121736671626e-05
# Statistically significant difference
# --------------------------------------------------------------------------------
# Fischer's F-test for method: Random
# Iteration bound: 2000
# Grid size: 5000
# F-statistic: 32.8846914802235
# p-value: 7.92301234575632e-06
# Statistically significant difference
# --------------------------------------------------------------------------------
# Fischer's F-test for method: Orthogonal
# Iteration bound: 2000
# Grid size: 5000
# F-statistic: 372.8108581437997
# p-value: 1.7408263719431716e-10
# Statistically significant difference
# --------------------------------------------------------------------------------
# Fischer's F-test for method: Latin
# Iteration bound: 2000
# Grid size: 5000
# F-statistic: 71.08766773429949
# p-value: 2.775255469877891e-07
# Statistically significant difference
# --------------------------------------------------------------------------------
# Fischer's F-test for method: Random
# Iteration bound: 2000
# Grid size: 5000
# F-statistic: 126.88750338768527
# p-value: 2.1406211581087575e-08
# Statistically significant difference
# --------------------------------------------------------------------------------
# Fischer's F-test for method: Orthogonal
# Iteration bound: 2000
# Grid size: 5000
# F-statistic: 3678.450572393579
# p-value: 5.995204332975845e-15
# Statistically significant difference
# --------------------------------------------------------------------------------
# Fischer's F-test for method: Latin
# Iteration bound: 2000
# Grid size: 5000
# F-statistic: 4081.141238526273
# p-value: 3.774758283725532e-15
# Statistically significant difference
# --------------------------------------------------------------------------------
# Fischer's F-test for method: Random
# Iteration bound: 2000
# Grid size: 5000
# F-statistic: 1579.289607091684
# p-value: 2.666755705149626e-13
# Statistically significant difference
# --------------------------------------------------------------------------------
# Fischer's F-test for method: Orthogonal
# Iteration bound: 2000
# Grid size: 5000
# F-statistic: 50893.266987148294
# p-value: 1.1102230246251565e-16
# Statistically significant difference
# --------------------------------------------------------------------------------
# Fischer's F-test for method: Latin
# Iteration bound: 2000
# Grid size: 5000
# F-statistic: 3.888123490081584
# p-value: 0.02780438938201757
# Statistically significant difference
# --------------------------------------------------------------------------------
# Fischer's F-test for method: Random
# Iteration bound: 2000
# Grid size: 5000
# F-statistic: 3.8585584257037673
# p-value: 0.028454348579703193
# Statistically significant difference
# --------------------------------------------------------------------------------
# Fischer's F-test for method: Orthogonal
# Iteration bound: 2000
# Grid size: 5000
# F-statistic: 9.866801065581452
# p-value: 0.001096509075122265
# Statistically significant difference
# --------------------------------------------------------------------------------
# Fischer's F-test for method: Latin
# Iteration bound: 2000
# Grid size: 5000
# F-statistic: 223.2170729691617
# p-value: 1.727644916016402e-09
# Statistically significant difference
# --------------------------------------------------------------------------------
# Fischer's F-test for method: Random
# Iteration bound: 2000
# Grid size: 5000
# F-statistic: 48.02506990346714
# p-value: 1.5437405648244251e-06
# Statistically significant difference
# --------------------------------------------------------------------------------
# Fischer's F-test for method: Orthogonal
# Iteration bound: 2000
# Grid size: 5000
# F-statistic: 136.51229806058348
# p-value: 1.5467277902914134e-08
# Statistically significant difference
# --------------------------------------------------------------------------------
# Fischer's F-test for method: Latin
# Iteration bound: 2000
# Grid size: 5000
# F-statistic: 57.409975156030335
# p-value: 7.085957920427433e-07
# Statistically significant difference
# --------------------------------------------------------------------------------
# Fischer's F-test for method: Random
# Iteration bound: 2000
# Grid size: 5000
# F-statistic: 12.44637623822109
# p-value: 0.00044375808264107697
# Statistically significant difference
# --------------------------------------------------------------------------------
# Fischer's F-test for method: Orthogonal
# Iteration bound: 2000
# Grid size: 5000
# F-statistic: 13.835517423857048
# p-value: 0.00029117204149864406
# Statistically significant difference
# --------------------------------------------------------------------------------
